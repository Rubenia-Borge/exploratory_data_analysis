# %%
import pandas as pd
from matplotlib import pyplot as plt

penguins_dataframe = pd.read_csv("../input/penguinsclassificationcsv/penguins-classification.csv")

# %%
penguins_dataframe.head(10)

# %%
import matplotlib.pyplot as plt
plt.plot(penguins_dataframe['Culmen Length (mm)'])
plt.ylabel('Culmen Length (mm)')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(penguins_dataframe['Culmen Depth (mm)'])
plt.ylabel('Culmen Depth (mm)')
plt.show()

# %%
plt.plot(penguins_dataframe['Culmen Length (mm)'], penguins_dataframe['Culmen Depth (mm)'])

# %%
names = penguins_dataframe['Culmen Length (mm)']
values = penguins_dataframe['Species']


 
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
len(penguins_dataframe)

# %%
penguins_dataframe.shape

# %%
penguins_dataframe.describe()

# %%
penguins_dataframe['Culmen Length (mm)'].value_counts()

# %%
penguins_dataframe['Culmen Depth (mm)'].value_counts()

# %%
penguins_dataframe["Species"].value_counts()

# %%
_ = penguins_dataframe.hist(figsize=(8, 4))

# %%
import seaborn

pairplot_figure = seaborn.pairplot(penguins_dataframe, hue="Species")

# %%
pairplot_figure = seaborn.pairplot(penguins_dataframe, hue="Species", height=4)

# %%
import numpy as np
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
X = penguins_dataframe[['Culmen Length (mm)','Culmen Depth (mm)']]
y = penguins_dataframe['Species']

# %%
print(X.head(10))

# %%
print(y.head(10))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

clf = DecisionTreeClassifier(max_leaf_nodes=3, random_state=0)
clf.fit(X_train, y_train)

# %%
n_nodes = clf.tree_.node_count
children_left = clf.tree_.children_left
children_right = clf.tree_.children_right
feature = clf.tree_.feature
threshold = clf.tree_.threshold

node_depth = np.zeros(shape=n_nodes, dtype=np.int64)
is_leaves = np.zeros(shape=n_nodes, dtype=bool)
stack = [(0, 0)]  # start with the root node id (0) and its depth (0)
while len(stack) > 0:
    # `pop` ensures each node is only visited once
    node_id, depth = stack.pop()
    node_depth[node_id] = depth

    # If the left and right child of a node is not the same we have a split
    # node
    is_split_node = children_left[node_id] != children_right[node_id]
    # If a split node, append left and right children and depth to `stack`
    # so we can loop through them
    if is_split_node:
        stack.append((children_left[node_id], depth + 1))
        stack.append((children_right[node_id], depth + 1))
    else:
        is_leaves[node_id] = True

print(
    "The binary tree structure has {n} nodes and has "
    "the following tree structure:\n".format(n=n_nodes)
)
for i in range(n_nodes):
    if is_leaves[i]:
        print(
            "{space}node={node} is a leaf node.".format(
                space=node_depth[i] * "\t", node=i
            )
        )
    else:
        print(
            "{space}node={node} is a split node: "
            "go to node {left} if X[:, {feature}] <= {threshold} "
            "else to node {right}.".format(
                space=node_depth[i] * "\t",
                node=i,
                left=children_left[i],
                feature=feature[i],
                threshold=threshold[i],
                right=children_right[i],
            )
        )

# %%
tree.plot_tree(clf)
plt.show()
